# %%
import numpy as np
import pandas as pd 

import pandas_datareader.data as web

# настройки визуализации
import matplotlib.pyplot as plt

# Не показывать Warnings
import warnings
warnings.simplefilter(action='ignore', category=Warning)

# %%
m2 = web.DataReader(name='M2SL', data_source='fred', start='1990-01-01')
m2
# Out:
#                M2SL
# DATE
# 1990-01-01   3166.8
# 1990-02-01   3179.2
# 1990-03-01   3190.1
# 1990-04-01   3201.6
# 1990-05-01   3200.6
# ...             ...
# 2025-08-01  22108.2
# 2025-09-01  22211.9
# 2025-10-01  22297.8
# 2025-11-01  22322.1
# 2025-12-01  22411.0
#
# [432 rows x 1 columns]

# %%
m2.index = m2.index.to_period("M")
m2
# Out:
#             M2SL
# DATE
# 1990-01   3166.8
# 1990-02   3179.2
# 1990-03   3190.1
# 1990-04   3201.6
# 1990-05   3200.6
# ...          ...
# 2025-08  22108.2
# 2025-09  22211.9
# 2025-10  22297.8
# 2025-11  22322.1
# 2025-12  22411.0
#
# [432 rows x 1 columns]

# %%
y = np.log(m2)
y
# Out:
#               M2SL
# DATE
# 1990-01   8.060477
# 1990-02   8.064385
# 1990-03   8.067808
# 1990-04   8.071406
# 1990-05   8.071094
# ...            ...
# 2025-08  10.003704
# 2025-09  10.008383
# 2025-10  10.012243
# 2025-11  10.013332
# 2025-12  10.017307
#
# [432 rows x 1 columns]

# %%
m2.plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
ax = m2.plot(title='M2 monthly')
# надпись по ос oX
ax.set_xlabel('Date')
# надпись по ос oY
ax.set_ylabel('US M2')
# отобразить сетку
ax.grid()
# удалим легенду
ax.legend().remove()

plt.show()

# %%
y.plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
ax = y.plot(title='log(M2) monthly')
# надпись по ос oX
ax.set_xlabel('Date')
# надпись по ос oY
ax.set_ylabel('US log(M2)')
# отобразить сетку
ax.grid()
# удалим легенду
ax.legend().remove()

plt.show()

# %%
y.diff().plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
y.diff().diff().plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
m2w = web.DataReader(name='WM2NS', data_source='fred', start='1990-01-01')
m2w
# Out:
#               WM2NS
# DATE
# 1990-01-01   3181.9
# 1990-01-08   3195.7
# 1990-01-15   3182.7
# 1990-01-22   3163.6
# 1990-01-29   3141.9
# ...             ...
# 2025-12-08  22460.0
# 2025-12-15  22545.8
# 2025-12-22  22631.6
# 2025-12-29  22679.6
# 2026-01-05  22692.2
#
# [1880 rows x 1 columns]

# %%
m2w_q = m2w.groupby(pd.Grouper(freq='Q')).mean()
m2w_q.index = m2w_q.index.to_period(freq='Q')
m2w_q
# Out:
#                WM2NS
# DATE
# 1990Q1   3177.076923
# 1990Q2   3204.946154
# 1990Q3   3235.630769
# 1990Q4   3266.250000
# 1991Q1   3302.341667
# ...              ...
# 2025Q1  21625.207692
# 2025Q2  21828.700000
# 2025Q3  22035.507692
# 2025Q4  22369.769231
# 2026Q1  22692.200000
#
# [145 rows x 1 columns]

# %%
m2w_q.plot()
# Out:
# <Axes: xlabel='DATE'>
