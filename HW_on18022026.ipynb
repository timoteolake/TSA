# %%
import numpy as np
import pandas as pd 

import pandas_datareader.data as web

# настройки визуализации
import matplotlib.pyplot as plt

# Не показывать Warnings
import warnings
warnings.simplefilter(action='ignore', category=Warning)

# %%
m2 = web.DataReader(name='WM2NS', data_source='fred', start='1990-01-01')
m2
# Out:
#               WM2NS
# DATE
# 1990-01-01   3181.9
# 1990-01-08   3195.7
# 1990-01-15   3182.7
# 1990-01-22   3163.6
# 1990-01-29   3141.9
# ...             ...
# 2025-12-08  22460.0
# 2025-12-15  22545.8
# 2025-12-22  22631.6
# 2025-12-29  22679.6
# 2026-01-05  22692.2
#
# [1880 rows x 1 columns]

# %%
m2_m = m2.resample("M").first()
m2_m.index = m2_m.index.to_period("M")
m2_m
# Out:
#            WM2NS
# DATE
# 1990-01   3181.9
# 1990-02   3169.4
# 1990-03   3188.9
# 1990-04   3206.1
# 1990-05   3195.1
# ...          ...
# 2025-09  22070.7
# 2025-10  22243.6
# 2025-11  22303.5
# 2025-12  22429.5
# 2026-01  22692.2
#
# [433 rows x 1 columns]

# %%
y = np.log(m2_m)
y
# Out:
#              WM2NS
# DATE
# 1990-01   8.065234
# 1990-02   8.061298
# 1990-03   8.067431
# 1990-04   8.072811
# 1990-05   8.069374
# ...            ...
# 2025-09  10.002006
# 2025-10  10.009810
# 2025-11  10.012499
# 2025-12  10.018132
# 2026-01  10.029777
#
# [433 rows x 1 columns]

# %%
m2_m.plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
ax = m2_m.plot(title='M2 monthly')
# надпись по ос oX
ax.set_xlabel('Date')
# надпись по ос oY
ax.set_ylabel('US M2')
# отобразить сетку
ax.grid()
# удалим легенду
ax.legend().remove()

plt.show()

# %%
y.plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
ax = y.plot(title='log(M2) monthly')
# надпись по ос oX
ax.set_xlabel('Date')
# надпись по ос oY
ax.set_ylabel('US log(M2)')
# отобразить сетку
ax.grid()
# удалим легенду
ax.legend().remove()

plt.show()
